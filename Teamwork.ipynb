# %% [markdown]
# Covid Vaccination

# %%
import csv
with open('country_vaccinations.csv') as File:
    reader = csv.DictReader(File)
    #for row in reader:
    #    print(row);
    File.close()

# %%
import pandas as pd
from matplotlib import pyplot as plt

data=pd.read_csv('country_vaccinations.csv')
data
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 15339     Zimbabwe      ZWE  2021-04-30            500342.0
# 15340     Zimbabwe      ZWE  2021-05-01            520299.0
# 15341     Zimbabwe      ZWE  2021-05-02            524199.0
# 15342     Zimbabwe      ZWE  2021-05-03            537516.0
# 15343     Zimbabwe      ZWE  2021-05-04            559777.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# ...

# %%
#country_list = pd.unique(data['country'])
#country_list

# %% [markdown]
# 1, The top10 country with most Vaccination Percentage
# 2, The top10 country with least Vaccination Percentage
# 3, The top10 country with most Daily Vaccination Rate
# 4, The top10 country with least Daily Vaccination Rate
# 5, Stand Distribution of Vaccination Percentage

# %% [markdown]
# 1, The top10 country with most Vaccination Percentage

# %%
df = pd.DataFrame(data)
df.loc[:,['country', 'total_vaccinations_per_hundred']].groupby('country').max().sort_values(by="total_vaccinations_per_hundred",ascending=False).head(10)
# Out:
#                       total_vaccinations_per_hundred
# country
# Gibraltar                                     211.08
# Seychelles                                    129.88
# Falkland Islands                              126.53
# Israel                                        121.03
# United Arab Emirates                          108.99
# Cayman Islands                                 99.96
# Bermuda                                        89.77
# San Marino                                     88.22
# Isle of Man                                    86.40
# Jersey                                         84.20

# %% [markdown]
# 2, The top10 country with least Vaccination Percentage

# %%
df = pd.DataFrame(data)
df.loc[:,['country', 'total_vaccinations_per_hundred']].groupby('country').max().sort_values(by="total_vaccinations_per_hundred",ascending=True).head(10)
# Out:
#                               total_vaccinations_per_hundred
# country
# Cameroon                                                0.00
# Democratic Republic of Congo                            0.00
# South Sudan                                             0.01
# Niger                                                   0.01
# Libya                                                   0.01
# Syria                                                   0.01
# Armenia                                                 0.02
# Papua New Guinea                                        0.03
# Mauritania                                              0.15
# Algeria                                                 0.17

# %% [markdown]
# 3, The top10 country with most Daily Vaccination Rate

# %%
df = pd.DataFrame(data)
df.loc[:,['country', 'daily_vaccinations_per_million']].groupby('country').max().sort_values(by="daily_vaccinations_per_million",ascending=False).head(10)
# Out:
#                   daily_vaccinations_per_million
# country
# Bhutan                                  118759.0
# Falkland Islands                         54264.0
# Gibraltar                                31700.0
# Mongolia                                 28519.0
# Seychelles                               24415.0
# Aruba                                    23350.0
# Anguilla                                 22064.0
# Israel                                   21366.0
# Curacao                                  21036.0
# San Marino                               20950.0

# %% [markdown]
# 4, The top10 country with least Daily Vaccination Rate

# %%
df = pd.DataFrame(data)
df.loc[:,['country', 'daily_vaccinations_per_million']].groupby('country').max().sort_values(by="daily_vaccinations_per_million",ascending=True).head(10)
# Out:
#                               daily_vaccinations_per_million
# country
# Niger                                                    3.0
# Democratic Republic of Congo                             3.0
# Syria                                                    4.0
# South Sudan                                              8.0
# Cameroon                                                15.0
# Papua New Guinea                                        15.0
# Bosnia and Herzegovina                                  80.0
# Algeria                                                 85.0
# Mauritania                                              88.0
# Taiwan                                                 118.0

# %% [markdown]
# 5, Stand Distribution of Vaccination Percentage

# %%
(df.loc[:,['country', 'total_vaccinations_per_hundred']].groupby('country').max())['total_vaccinations_per_hundred'].std()
# Out:
# 31.494854748731093

# %%
(df.loc[:,['country', 'total_vaccinations_per_hundred']].groupby('country').max())['total_vaccinations_per_hundred'].mean()
# Out:
# 24.175025641025666
