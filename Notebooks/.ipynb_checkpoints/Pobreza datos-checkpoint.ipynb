# %% [markdown]
# ## Carga de librerías

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import sklearn
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances_argmin_min
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import scale
import sklearn.metrics as sm
from sklearn import datasets

# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')

# %% [markdown]
# # GDP per cápita 2018

# %%
import os 
import pandas as pd
nb_path = os.path.abspath("Pobreza datos.ipynb")
gdp_csv = os.path.join(os.path.dirname(nb_path), "Datasets/GDPpC2018.csv")
gdp_data = pd.read_csv(gdp_csv, engine='python')

# %%
gdp_data
# Out:
#      ï»¿"LOCATION"                                            Country  \
# 0              AUS                                          Australia
# 1              AUS                                          Australia
# 2              AUS                                          Australia
# 3              AUS                                          Australia
# 4              AUS                                          Australia
# ...            ...                                                ...
# 1184     EU27_2020  European Union â€“ 27 countries (from 01/02/2020)
# 1185     EU27_2020  European Union â€“ 27 countries (from 01/02/2020)
# 1186     EU27_2020  European Union â€“ 27 countries (from 01/02/2020)
# 1187     EU27_2020  European Union â€“ 27 countries (from 01/02/2020)
# 1188     EU27_2020  European Union â€“ 27 countries (from 01/02/2020)
#
#        SUBJECT                                            Subject MEASURE  \
# 0        T_GDP             Gross Domestic Product (GDP); millions       C
# 1     T_GDPPOP                         GDP per head of population       C
# 2     T_GDPHRS                                GDP per hour worked       C
# 3     T_GDPEMP                            GDP per person employed       C
# 4        T_GDP             Gross Domestic Product (GDP); millions     CPC
# ...        ...                                                ...     ...
# 1184  T_GDPHRS                                GDP per hour worked   VPVOB
# 1185   T_HRSTO        Hours worked for total employment; millions   PEHRS
# 1186  T_GPHRPO  Gap in labour utilisation with respect to the USA     GAP
# 1187     T_GDP             Gross Domestic Product (GDP); millions   VPVOB
# 1188  T_GDPEMP                            GDP per person employed     CPC
#
#                                 Measure  TIME  Time Unit Code  \
# 0     National currency, current prices  2018  2018    NATCUR
# 1     National currency, current prices  2018  2018    NATCUR
# 2     National currency, current prices  2018  2018    NATCUR
# 3     National currency, current prices  2018  2018    NATCUR
# 4     USD, current prices, current PPPs  2018  2018       USD
# ...                                 ...   ...   ...       ...
# 1184    USD, constant prices, 2015 PPPs  2018  2018       USD
# 1185                      Persons/Hours  2018  2018      HOUR
# 1186                    Gap in % points  2018  2018        PC
# 1187    USD, constant prices, 2015 PPPs  2018  2018       USD
# 1188  USD, current prices, current PPPs  2018  2018       USD
#
#                    Unit  PowerCode Code PowerCode Reference Period Code  \
# 0     National currency               6  Millions                   NaN
# 1     National currency               0     Units                   NaN
# 2     National currency               0     Units                   NaN
# 3     National currency               0     Units                   NaN
# 4             US Dollar               6  Millions                   NaN
# ...                 ...             ...       ...                   ...
# 1184          US Dollar               0     Units                   NaN
# 1185              Hours               6  Millions                   NaN
# 1186         Percentage               0     Units                   NaN
# 1187          US Dollar               6  Millions                   NaN
# 1188          US Dollar               0     Units                   NaN
#
#      Reference Period         Value Flag Codes            Flags
# 0                 NaN  1.952680e+06        NaN              NaN
# 1                 NaN  7.816129e+04        NaN              NaN
# 2                 NaN  8.810204e+01          E  Estimated value
# 3                 NaN  1.517386e+05          E  Estimated value
# 4                 NaN  1.326164e+06        NaN              NaN
# ...               ...           ...        ...              ...
# 1184              NaN  5.389208e+01        NaN              NaN
# 1185              NaN  3.375552e+05        NaN              NaN
# 1186              NaN -1.049154e+01        NaN              NaN
# 1187              NaN  1.819155e+07        NaN              NaN
# 1188              NaN  9.083555e+04        NaN              NaN
#
# [1189 rows x 17 columns]

# %%
gdp_data.shape
# Out:
# (1189, 17)

# %%
# aquí mostramos a todos los registros de los países en la base de datos
# se repiten porque hay varios datos sobre cada país, por lo que haremos filtro
print(gdp_data.groupby('Country').size())
# Out:
# Country
# Australia                                                                      26
# Austria                                                                        26
# BRIICS economies - Brazil, Russia, India, Indonesia, China and South Africa    12
# Belgium                                                                        26
# Brazil                                                                         15
# Canada                                                                         26
# Chile                                                                          26
# China (People's Republic of)                                                   15
# Colombia                                                                       15
# Costa Rica                                                                     26
# Czech Republic                                                                 26
# Denmark                                                                        26
# Estonia                                                                        26
# Euro area (19 countries)                                                       25
# European Union â€“ 27 countries (from 01/02/2020)                              25
# Finland                                                                        26
# France                                                                         26
# G7                                                                             22
# Germany                                                                        26
# Greece                                                                         26
# Hungary                                                                        26
# Iceland                                                                        25
# India                                                                          15
# Indonesia                                                                      15
# Ireland                                                                        26
# Israel                                                                         26
# Italy                                                                          26
# Japan                                                                          26
# Korea                                                                          26
# Latvia                                                                         26
# Lithuania                                                                      26
# Luxembourg                                                                     26
# Mexico                                                                         26
# Netherlands                                                                    26
# New Zealand                                                                    26
# Norway                                                                         26
# OECD - Total                                                                   21
# Poland                                                                         26
# Portugal                                                                       26
# Russia                                                                         26
# Slovak Republic                                                                26
# Slovenia                                                                       26
# South Africa                                                                   26
# Spain                                                                          26
# Sweden                                                                         26
# Switzerland                                                                    26
# Turkey                                                                         25
# United Kingdom                                                                 26
# United States                                                                  23
# dtype: int64

# %% [markdown]
# ### Buscamos el dato que queremos
# En este caso buscamos el GDP, GDP per head of population y vemos que hay 193 registros:
# "Gross Domestic Product (GDP); millions                      193"
# "GDP per head of population                                  191"
#
# Hay otros datos interesantes como:
# "Average hours worked per person employed                     43"

# %%
print(gdp_data.groupby('Subject').size())
# Out:
# Subject
# Average hours worked per person employed                     43
# GDP per head of population                                  191
# GDP per hour worked                                         170
# GDP per person employed                                     193
# Gap in GDP per capita with respect to the USA                48
# Gap in GDP per hour worked with respect to the USA           42
# Gap in labour utilisation with respect to the USA            42
# Gross Domestic Product (GDP); millions                      193
# Gross national income per hour worked                        40
# Hours worked for total employment; millions                  43
# Labour utilisation (hours worked per head of population)     86
# Total employment (number of persons employed); thousands     49
# Total population; persons; thousands                         49
# dtype: int64

# %% [markdown]
# ### Aplicamos filtros
# Una vez aplicados, podremos ver la tabla y sobre lo que trata de manera más clara

# %%
gdp_pop = gdp_data[(gdp_data['SUBJECT'] == 'T_GDPPOP') & (gdp_data['Unit Code'] == 'USD') & 
                   (gdp_data['MEASURE'] == 'CPC')]
gdp_pop = gdp_pop.drop(['ï»¿"LOCATION"','Unit', 'PowerCode Code','MEASURE','TIME','PowerCode',
              'Reference Period Code','Reference Period','Flags','Flag Codes','SUBJECT'], axis = 1)
gdp_pop
# Out:
#                                                 Country  \
# 5                                             Australia
# 22                                              Austria
# 39                                              Belgium
# 56                                               Canada
# 73                                       Czech Republic
# 90                                              Denmark
# 107                                             Finland
# 124                                              France
# 141                                             Germany
# 158                                              Greece
# 175                                             Hungary
# 192                                             Iceland
# 209                                             Ireland
# 226                                               Italy
# 243                                               Japan
# 260                                               Korea
# 277                                          Luxembourg
# 294                                              Mexico
# 311                                         Netherlands
# 328                                         New Zealand
# 345                                              Norway
# 362                                              Poland
# 379                                            Portugal
# 396                                     Slovak Republic
# 413                                               Spain
# 430                                              Sweden
# 447                                         Switzerland
# 464                                              Turkey
# 481                                      United Kingdom
# 498                                       United States
# 514                                              Brazil
# 527                                               Chile
# 543                        China (People's Republic of)
# 556                                             Estonia
# 572                                               India
# 584                                           Indonesia
# 597                                              Israel
# 614                                              Russia
# 631                                            Slovenia
# 647                                        South Africa
# 656   BRIICS economies - Brazil, Russia, India, Indo...
# 966                                                  G7
# 995                                        OECD - Total
# 1007                                           Colombia
# 1023                                             Latvia
# 1048                                          Lithuania
# 1072                           Euro area (19 countries)
# 1107                                         Costa Rica
# 1169  European Union â€“ 27 countries (from 01/02/2020)
#
#                          Subject                            Measure  Time  \
# 5     GDP per head of population  USD, current prices, current PPPs  2018
# 22    GDP per head of population  USD, current prices, current PPPs  2018
# 39    GDP per head of population  USD, current prices, current PPPs  2018
# 56    GDP per head of population  USD, current prices, current PPPs  2018
# 73    GDP per head of population  USD, current prices, current PPPs  2018
# 90    GDP per head of population  USD, current prices, current PPPs  2018
# 107   GDP per head of population  USD, current prices, current PPPs  2018
# 124   GDP per head of population  USD, current prices, current PPPs  2018
# 141   GDP per head of population  USD, current prices, current PPPs  2018
# 158   GDP per head of population  USD, current prices, current PPPs  2018
# 175   GDP per head of population  USD, current prices, current PPPs  2018
# 192   GDP per head of population  USD, current prices, current PPPs  2018
# 209   GDP per head of population  USD, current prices, current PPPs  2018
# 226   GDP per head of population  USD, current prices, current PPPs  2018
# 243   GDP per head of population  USD, current prices, current PPPs  2018
# 260   GDP per head of population  USD, current prices, current PPPs  2018
# 277   GDP per head of population  USD, current prices, current PPPs  2018
# 294   GDP per head of population  USD, current prices, current PPPs  2018
# 311   GDP per head of population  USD, current prices, current PPPs  2018
# 328   GDP per head of population  USD, current prices, current PPPs  2018
# 345   GDP per head of population  USD, current prices, current PPPs  2018
# 362   GDP per head of population  USD, current prices, current PPPs  2018
# 379   GDP per head of population  USD, current prices, current PPPs  2018
# 396   GDP per head of population  USD, current prices, current PPPs  2018
# 413   GDP per head of population  USD, current prices, current PPPs  2018
# 430   GDP per head of population  USD, current prices, current PPPs  2018
# 447   GDP per head of population  USD, current prices, current PPPs  2018
# 464   GDP per head of population  USD, current prices, current PPPs  2018
# 481   GDP per head of population  USD, current prices, current PPPs  2018
# 498   GDP per head of population  USD, current prices, current PPPs  2018
# 514   GDP per head of population  USD, current prices, current PPPs  2018
# 527   GDP per head of population  USD, current prices, current PPPs  2018
# 543   GDP per head of population  USD, current prices, current PPPs  2018
# 556   GDP per head of population  USD, current prices, current PPPs  2018
# 572   GDP per head of population  USD, current prices, current PPPs  2018
# 584   GDP per head of population  USD, current prices, current PPPs  2018
# 597   GDP per head of population  USD, current prices, current PPPs  2018
# 614   GDP per head of population  USD, current prices, current PPPs  2018
# 631   GDP per head of population  USD, current prices, current PPPs  2018
# 647   GDP per head of population  USD, current prices, current PPPs  2018
# 656   GDP per head of population  USD, current prices, current PPPs  2018
# 966   GDP per head of population  USD, current prices, current PPPs  2018
# 995   GDP per head of population  USD, current prices, current PPPs  2018
# 1007  GDP per head of population  USD, current prices, current PPPs  2018
# 1023  GDP per head of population  USD, current prices, current PPPs  2018
# 1048  GDP per head of population  USD, current prices, current PPPs  2018
# 1072  GDP per head of population  USD, current prices, current PPPs  2018
# 1107  GDP per head of population  USD, current prices, current PPPs  2018
# 1169  GDP per head of population  USD, current prices, current PPPs  2018
#
#      Unit Code          Value
# 5          USD   53083.298202
# 22         USD   57068.534859
# 39         USD   52668.407369
# 56         USD   50239.988271
# 73         USD   41147.631519
# 90         USD   57459.169658
# 107        USD   49749.057503
# 124        USD   46456.107114
# 141        USD   54954.686585
# 158        USD   29680.902374
# 175        USD   31831.981050
# 192        USD   58225.803799
# 209        USD   85027.004207
# 226        USD   43097.264513
# 243        USD   41724.030338
# 260        USD   42486.739803
# 277        USD  116480.803410
# 294        USD   20518.580821
# 311        USD   57899.824977
# 328        USD   43738.114664
# 345        USD   69709.381589
# 362        USD   31613.688152
# 379        USD   34931.859916
# 396        USD   31561.916950
# 413        USD   40780.287319
# 430        USD   53553.312075
# 447        USD   71705.600372
# 464        USD   28263.241822
# 481        USD   47163.170630
# 498        USD   63043.046469
# 514        USD   15272.368773
# 527        USD   24686.142353
# 543        USD   15584.651285
# 556        USD   36406.045789
# 572        USD    6678.341255
# 584        USD   11765.291834
# 597        USD   40351.274181
# 614        USD   28893.861784
# 631        USD   38952.062689
# 647        USD   12950.451443
# 656        USD   12322.879613
# 966        USD   53639.582789
# 995        USD   45153.748098
# 1007       USD   15256.201624
# 1023       USD   30814.222453
# 1048       USD   36346.416600
# 1072       USD   47548.319553
# 1107       USD   20988.161597
# 1169       USD   42055.470258

# %% [markdown]
# ### Nuevo dataframe
# Hacemos un nuevo dataframe para que sean sólamente los países y no conjuntos, como el G7, economías BRIICS, etc... y también lo hacemos funcional para la comparación con el MPI.
# Por ahora lo mostraremos organizado en orden descendente.

# %%
gdp_df = gdp_pop.drop(index=[656,966,995,1072,1169],columns=['Subject','Measure','Time','Unit Code'])
gdp_df.sort_values(by=['Value'],ascending=False)
# Out:
#                            Country          Value
# 5                        Australia   53083.298202
# 22                         Austria   57068.534859
# 39                         Belgium   52668.407369
# 56                          Canada   50239.988271
# 73                  Czech Republic   41147.631519
# 90                         Denmark   57459.169658
# 107                        Finland   49749.057503
# 124                         France   46456.107114
# 141                        Germany   54954.686585
# 158                         Greece   29680.902374
# 175                        Hungary   31831.981050
# 192                        Iceland   58225.803799
# 209                        Ireland   85027.004207
# 226                          Italy   43097.264513
# 243                          Japan   41724.030338
# 260                          Korea   42486.739803
# 277                     Luxembourg  116480.803410
# 294                         Mexico   20518.580821
# 311                    Netherlands   57899.824977
# 328                    New Zealand   43738.114664
# 345                         Norway   69709.381589
# 362                         Poland   31613.688152
# 379                       Portugal   34931.859916
# 396                Slovak Republic   31561.916950
# 413                          Spain   40780.287319
# 430                         Sweden   53553.312075
# 447                    Switzerland   71705.600372
# 464                         Turkey   28263.241822
# 481                 United Kingdom   47163.170630
# 498                  United States   63043.046469
# 514                         Brazil   15272.368773
# 527                          Chile   24686.142353
# 543   China (People's Republic of)   15584.651285
# 556                        Estonia   36406.045789
# 572                          India    6678.341255
# 584                      Indonesia   11765.291834
# 597                         Israel   40351.274181
# 614                         Russia   28893.861784
# 631                       Slovenia   38952.062689
# 647                   South Africa   12950.451443
# 1007                      Colombia   15256.201624
# 1023                        Latvia   30814.222453
# 1048                     Lithuania   36346.416600
# 1107                    Costa Rica   20988.161597

# %%
# Out:
#                            Country          Value
# 277                     Luxembourg  116480.803410
# 209                        Ireland   85027.004207
# 447                    Switzerland   71705.600372
# 345                         Norway   69709.381589
# 498                  United States   63043.046469
# 192                        Iceland   58225.803799
# 311                    Netherlands   57899.824977
# 90                         Denmark   57459.169658
# 22                         Austria   57068.534859
# 141                        Germany   54954.686585
# 430                         Sweden   53553.312075
# 5                        Australia   53083.298202
# 39                         Belgium   52668.407369
# 56                          Canada   50239.988271
# 107                        Finland   49749.057503
# 481                 United Kingdom   47163.170630
# 124                         France   46456.107114
# 328                    New Zealand   43738.114664
# 226                          Italy   43097.264513
# 260                          Korea   42486.739803
# 243                          Japan   41724.030338
# 73                  Czech Republic   41147.631519
# 413                          Spain   40780.287319
# 597                         Israel   40351.274181
# 631                       Slovenia   38952.062689
# 556                        Estonia   36406.045789
# 1048                     Lithuania   36346.416600
# 379                       Portugal   34931.859916
# 175                        Hungary   31831.981050
# 362                         Poland   31613.688152
# 396                Slovak Republic   31561.916950
# 1023                        Latvia   30814.222453
# 158                         Greece   29680.902374
# 614                         Russia   28893.861784
# 464                         Turkey   28263.241822
# 527                          Chile   24686.142353
# 1107                    Costa Rica   20988.161597
# 294                         Mexico   20518.580821
# 543   China (People's Republic of)   15584.651285
# 514                         Brazil   15272.368773
# 1007                      Colombia   15256.201624
# 647                   South Africa   12950.451443
# 584                      Indonesia   11765.291834
# 572                          India    6678.341255

# %% [markdown]
# # Datos estadísticos nacionales

# %%
import os 
import pandas as pd
nb_path = os.path.abspath("Pobreza datos.ipynb")
mpi_n_csv = os.path.join(os.path.dirname(nb_path), "Datasets/MPI_national.csv")
datos=pd.read_csv(mpi_n_csv, engine='python')

# %%
datos
# Out:
#      ISO                   Country  MPI Urban  Headcount Ratio Urban  \
# 0    KAZ                Kazakhstan      0.000                    0.0
# 1    SRB                    Serbia      0.000                    0.1
# 2    KGZ                Kyrgyzstan      0.000                    0.1
# 3    TUN                   Tunisia      0.000                    0.1
# 4    ARM                   Armenia      0.001                    0.2
# ..   ...                       ...        ...                    ...
# 97   CAF  Central African Republic      0.289                   58.2
# 98   LBR                   Liberia      0.290                   60.5
# 99   SOM                   Somalia      0.293                   55.9
# 100  TCD                      Chad      0.351                   64.8
# 101  SSD               South Sudan      0.459                   82.5
#
#      Intensity of Deprivation Urban  MPI Rural  Headcount Ratio Rural  \
# 0                              33.3      0.000                   0.09
# 1                              41.4      0.002                   0.50
# 2                              40.2      0.003                   0.70
# 3                              35.6      0.012                   3.18
# 4                              33.3      0.001                   0.39
# ..                              ...        ...                    ...
# 97                             49.7      0.519                  89.79
# 98                             48.0      0.481                  84.86
# 99                             52.4      0.651                  96.92
# 100                            54.1      0.609                  93.41
# 101                            55.7      0.591                  94.00
#
#      Intensity of Deprivation Rural
# 0                              33.3
# 1                              40.3
# 2                              37.1
# 3                              38.7
# 4                              36.9
# ..                              ...
# 97                             57.8
# 98                             56.6
# 99                             67.2
# 100                            65.2
# 101                            62.8
#
# [102 rows x 8 columns]

# %%
filas=len(datos)
filas
# Out:
# 102

# %%
tipo_datos = pd.read_csv ("MPI_national.csv")

# %%
tipo_datos.dtypes
# Out:
# ISO                                object
# Country                            object
# MPI Urban                         float64
# Headcount Ratio Urban             float64
# Intensity of Deprivation Urban    float64
# MPI Rural                         float64
# Headcount Ratio Rural             float64
# Intensity of Deprivation Rural    float64
# dtype: object

# %%
datos['MPI Urban'].describe()
# Out:
# count    102.000000
# mean       0.078343
# std        0.093693
# min        0.000000
# 25%        0.007250
# 50%        0.034500
# 75%        0.125750
# max        0.459000
# Name: MPI Urban, dtype: float64

# %%
datos['Headcount Ratio Urban'].describe()
# Out:
# count    102.000000
# mean      16.809804
# std       18.498448
# min        0.000000
# 25%        1.950000
# 50%        8.400000
# 75%       27.575000
# max       82.500000
# Name: Headcount Ratio Urban, dtype: float64

# %%
datos['Intensity of Deprivation Urban'].describe()
# Out:
# count    102.000000
# mean      41.678431
# std        5.135908
# min       33.300000
# 25%       37.200000
# 50%       41.550000
# 75%       45.675000
# max       55.700000
# Name: Intensity of Deprivation Urban, dtype: float64

# %%
datos['MPI Rural'].describe()
# Out:
# count    102.000000
# mean       0.214676
# std        0.201208
# min        0.000000
# 25%        0.025000
# 50%        0.160000
# 75%        0.384500
# max        0.669000
# Name: MPI Rural, dtype: float64

# %%
datos['Headcount Ratio Rural'].describe()
# Out:
# count    102.000000
# mean      40.036176
# std       33.270714
# min        0.090000
# 25%        6.745000
# 50%       36.055000
# 75%       70.130000
# max       96.920000
# Name: Headcount Ratio Rural, dtype: float64

# %%
datos['Intensity of Deprivation Rural'].describe()
# Out:
# count    102.000000
# mean      46.824510
# std        8.783191
# min       33.300000
# 25%       40.225000
# 50%       44.800000
# 75%       53.425000
# max       69.500000
# Name: Intensity of Deprivation Rural, dtype: float64

# %%
datos['Headcount Ratio Rural'].median()
# Out:
# 36.055

# %% [markdown]
# # Datos estadísticos subnacionales

# %%
import os
import pandas as pd 
from matplotlib import pyplot as plt 
nb_path = os.path.abspath("Pobreza datos.ipynb")
mpi_s_csv = os.path.join(os.path.dirname(nb_path), "Datasets/MPI_subnational.csv")
datos=pd.read_csv(mpi_s_csv, engine='python')

# %%
data
# Out:
#     ISO_country_code      Country Sub_national_region        World_region  \
# 0                AFG  Afghanistan          Badakhshan          South Asia
# 1                AFG  Afghanistan             Badghis          South Asia
# 2                AFG  Afghanistan             Baghlan          South Asia
# 3                AFG  Afghanistan               Balkh          South Asia
# 4                AFG  Afghanistan              Bamyan          South Asia
# ..               ...          ...                 ...                 ...
# 979              ZWE     Zimbabwe    Mashonaland West  Sub-Saharan Africa
# 980              ZWE     Zimbabwe            Masvingo  Sub-Saharan Africa
# 981              ZWE     Zimbabwe  Matabeleland North  Sub-Saharan Africa
# 982              ZWE     Zimbabwe  Matabeleland South  Sub-Saharan Africa
# 983              ZWE     Zimbabwe            Midlands  Sub-Saharan Africa
#
#      MPI_National  MPI_Regional  Headcount_Ratio_Regional  \
# 0           0.295         0.387                      67.5
# 1           0.295         0.466                      79.3
# 2           0.295         0.300                      59.7
# 3           0.295         0.301                      55.7
# 4           0.295         0.325                      61.0
# ..            ...           ...                       ...
# 979         0.152         0.192                      43.7
# 980         0.152         0.174                      38.9
# 981         0.152         0.238                      53.4
# 982         0.152         0.164                      38.2
# 983         0.152         0.176                      40.5
#
#      Intensity_of_deprivation_Regional
# 0                                 57.3
# 1                                 58.8
# 2                                 50.3
# 3                                 54.1
# 4                                 53.3
# ..                                 ...
# 979                               44.1
# 980                               44.7
# 981                               44.5
# 982                               42.8
# 983                               43.5
#
# [984 rows x 8 columns]

# %%
type (data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.ISO_country_code
# Out:
# 0      AFG
# 1      AFG
# 2      AFG
# 3      AFG
# 4      AFG
#       ...
# 979    ZWE
# 980    ZWE
# 981    ZWE
# 982    ZWE
# 983    ZWE
# Name: ISO_country_code, Length: 984, dtype: object

# %%
data["ISO_country_code"].describe()
# Out:
# count     984
# unique     78
# top       NGA
# freq       37
# Name: ISO_country_code, dtype: object

# %% [markdown]
# No se puede sacar mediana debido a que no son número por lo tanto no se puden covertir los datos de una cadena de caracteres "string" a números "float".

# %%
data.Country
# Out:
# 0      Afghanistan
# 1      Afghanistan
# 2      Afghanistan
# 3      Afghanistan
# 4      Afghanistan
#           ...
# 979       Zimbabwe
# 980       Zimbabwe
# 981       Zimbabwe
# 982       Zimbabwe
# 983       Zimbabwe
# Name: Country, Length: 984, dtype: object

# %%
data["Country"].describe()
# Out:
# count         984
# unique         78
# top       Nigeria
# freq           37
# Name: Country, dtype: object

# %%
data.Sub_national_region
# Out:
# 0              Badakhshan
# 1                 Badghis
# 2                 Baghlan
# 3                   Balkh
# 4                  Bamyan
#               ...
# 979      Mashonaland West
# 980              Masvingo
# 981    Matabeleland North
# 982    Matabeleland South
# 983              Midlands
# Name: Sub_national_region, Length: 984, dtype: object

# %%
data["Sub_national_region"].describe()
# Out:
# count         984
# unique        928
# top       Eastern
# freq            8
# Name: Sub_national_region, dtype: object

# %%
data.World_region
# Out:
# 0              South Asia
# 1              South Asia
# 2              South Asia
# 3              South Asia
# 4              South Asia
#               ...
# 979    Sub-Saharan Africa
# 980    Sub-Saharan Africa
# 981    Sub-Saharan Africa
# 982    Sub-Saharan Africa
# 983    Sub-Saharan Africa
# Name: World_region, Length: 984, dtype: object

# %%
data["World_region"].describe()
# Out:
# count                    984
# unique                     6
# top       Sub-Saharan Africa
# freq                     431
# Name: World_region, dtype: object

# %%
data.MPI_National
# Out:
# 0      0.295
# 1      0.295
# 2      0.295
# 3      0.295
# 4      0.295
#        ...
# 979    0.152
# 980    0.152
# 981    0.152
# 982    0.152
# 983    0.152
# Name: MPI_National, Length: 984, dtype: float64

# %%
data["MPI_National"].describe()
# Out:
# count    984.000000
# mean       0.204107
# std        0.160248
# min        0.006000
# 25%        0.066000
# 50%        0.174000
# 75%        0.303000
# max        0.605000
# Name: MPI_National, dtype: float64

# %%
data["MPI_National"].median()
# Out:
# 0.174

# %%
data.MPI_Regional
# Out:
# 0      0.387
# 1      0.466
# 2      0.300
# 3      0.301
# 4      0.325
#        ...
# 979    0.192
# 980    0.174
# 981    0.238
# 982    0.164
# 983    0.176
# Name: MPI_Regional, Length: 984, dtype: float64

# %%
data["MPI_Regional"].describe()
# Out:
# count    984.000000
# mean       0.211330
# std        0.183621
# min        0.000000
# 25%        0.053000
# 50%        0.155000
# 75%        0.341500
# max        0.744000
# Name: MPI_Regional, dtype: float64

# %%
data["MPI_Regional"].median()
# Out:
# 0.155

# %%
plt.plot(data.MPI_National, data.MPI_Regional, "*")
plt.show()

# %%
data.Headcount_Ratio_Regional
# Out:
# 0      67.5
# 1      79.3
# 2      59.7
# 3      55.7
# 4      61.0
#        ...
# 979    43.7
# 980    38.9
# 981    53.4
# 982    38.2
# 983    40.5
# Name: Headcount_Ratio_Regional, Length: 984, dtype: float64

# %%
data["Headcount_Ratio_Regional"].describe()
# Out:
# count    984.000000
# mean      40.184451
# std       29.981403
# min        0.000000
# 25%       12.475000
# 50%       33.950000
# 75%       66.725000
# max       99.000000
# Name: Headcount_Ratio_Regional, dtype: float64

# %%
data["Headcount_Ratio_Regional"].median()
# Out:
# 33.95

# %%
data.Intensity_of_deprivation_Regional
# Out:
# 0      57.3
# 1      58.8
# 2      50.3
# 3      54.1
# 4      53.3
#        ...
# 979    44.1
# 980    44.7
# 981    44.5
# 982    42.8
# 983    43.5
# Name: Intensity_of_deprivation_Regional, Length: 984, dtype: float64

# %%
data["Intensity_of_deprivation_Regional"].describe()
# Out:
# count    983.000000
# mean      47.180977
# std        8.047225
# min       33.300000
# 25%       41.400000
# 50%       45.600000
# 75%       51.900000
# max       75.900000
# Name: Intensity_of_deprivation_Regional, dtype: float64

# %%
data["Intensity_of_deprivation_Regional"].median()
# Out:
# 45.6

# %%
plt.plot(data.Headcount_Ratio_Regional, data.Intensity_of_deprivation_Regional, "+")
plt.show()

# %%
data.head()
# Out:
#   ISO_country_code      Country Sub_national_region World_region  \
# 0              AFG  Afghanistan          Badakhshan   South Asia
# 1              AFG  Afghanistan             Badghis   South Asia
# 2              AFG  Afghanistan             Baghlan   South Asia
# 3              AFG  Afghanistan               Balkh   South Asia
# 4              AFG  Afghanistan              Bamyan   South Asia
#
#    MPI_National  MPI_Regional  Headcount_Ratio_Regional  \
# 0         0.295         0.387                      67.5
# 1         0.295         0.466                      79.3
# 2         0.295         0.300                      59.7
# 3         0.295         0.301                      55.7
# 4         0.295         0.325                      61.0
#
#    Intensity_of_deprivation_Regional
# 0                               57.3
# 1                               58.8
# 2                               50.3
# 3                               54.1
# 4                               53.3

# %% [markdown]
# # Conclusiones sobre los datos.

# %% [markdown]
# En las prmeras cuatro columnas de la base de datos no es posibe sacar la mediana, los máximos y los mínimos, de los grupos de datos, debido a que son datos strings y esto solo esposible debido a que solo se pueden hacer con datos de tipo float, pero con la función de drscribe  obtuvimos el número de varabes de la columa determinada, la frecuencia y variable top. Por otro lado en las Medidas de Pobreza Multidimensional, con datos númericos empezamos a tener que el promedio del MPI Nacional es de 0.20 lo que nos muestra un indice alto, lo que nos indica que un mayor porcentaje de los paises tiene altos niveles de pobresa nacional y en comparacion con el promedio del MPI Regional que es de 0.21 que es un poco más alto que el anterior (describiendo un indice de pobreza aun más alto en sectres más pequeños de la nación), en la columna de de MPI Nacional tenemos un máximo de 0.605,un mínimo de 0.006, una mediana de 0.174, lo que nos indica que existe un rango demasiado amplio entre los datos (observando en máximo y el mínimo) y se tiene una mediana que nos indica en que rango se tienen más los datos. Por otro lados en la columna de MPI Regional se tiene un máximo de 0.744, un mínimo de 0.000 y una mediana de 0.155, lo que nos índica un rango aún más rande que en la anterior columna debido a que ahora podemos saber que se tiene datos con un indice de pobreza de cero (lo que es un buen aspecto)y con la mediana podemos tener una variable ni siquiera cerca del valor máximo, si lo ponemos en cuestion de personas y lugares, podemos pensar que en la nacion tenemos lugares con una buena economia y empleos dandonos como resultados rangos amplios en las columnas anteriormente mencionadas. Al poner estas columnas en una gráfica para poder ver de manera visual el comportamiento de las varibales podemos observar que los datos mayormente se acumulan entre los puntos 0 al 0.3, esto nos quiere decir que ambas columnas tiene indices de pobreza multidimensional respectivamente bajos pero al ser demasiados hace que los promedios sean amplios.

# %% [markdown]
# Ahora analizando las últimas dos columnas y sus variables podemos notar que en la columna de "Headcount_Ratio_Regional" tenemos una media de 40.18, un máximo de 99, un mínimo de 0 y una mediana de 33.95, estos datos nos muestran que la taza de recuento nacional tienen un rango entre el máx y el mín muy amplio, la media nos indica que su promedio esta por debajo de lo que se podria pronosticar (suponinendo que del 0 al 99 las variables fueran crecientes por lo tante podemos concluir con ayuda de la mediana que se tienen más datas menores.
# En la columna de "Intensity_of_deprivation_Regional" tenemos una media de 47.18, un valor máximo de 75.9, un valor mínimo de 33.3 y una mediana de 45.6.
# Comparando estas columnas y colocandolas en una gráfica observamos que los datos se acumulan al inicio de los rangos de 0 a 20 con respecto a x y de 0 a 50 con respecto a y. Lo que nos indica tazas de de recuento e intensidades de privación respectivamente bajos.
