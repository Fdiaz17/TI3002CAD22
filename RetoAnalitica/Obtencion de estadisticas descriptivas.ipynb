# %% [markdown]
# # Actividad Evaluable: Obtención de estadisticas descriptivas
#
# Eduardo Rodriguez Gil
# Jose Manuel Neri Villeda
# Hector Calderon

# %%
import pandas as pd
from matplotlib import pyplot as plt

data = pd.read_csv('Bitcoin.csv')

# %%
data
# Out:
#               Date    Price     Open     High      Low   Volume  Change
# 0     Apr 25, 2021  49561.9  50088.2  50438.8  49226.5   66.26K  -1.05%
# 1     Apr 24, 2021  50088.9  51140.8  51183.0  48775.2   82.25K  -2.06%
# 2     Apr 23, 2021  51143.6  51707.1  52099.9  47659.4  214.46K  -1.13%
# 3     Apr 22, 2021  51729.5  53821.3  55408.4  50590.9  168.13K  -3.88%
# 4     Apr 21, 2021  53820.2  56479.5  56764.4  53657.6  100.26K  -4.71%
# ...            ...      ...      ...      ...      ...      ...     ...
# 3930  Jul 22, 2010      0.1      0.1      0.1      0.1    2.16K   0.00%
# 3931  Jul 21, 2010      0.1      0.1      0.1      0.1    0.58K   0.00%
# 3932  Jul 20, 2010      0.1      0.1      0.1      0.1    0.26K   0.00%
# 3933  Jul 19, 2010      0.1      0.1      0.1      0.1    0.57K   0.00%
# 3934  Jul 18, 2010      0.1      0.0      0.1      0.1    0.08K   0.00%
#
# [3935 rows x 7 columns]

# %%
filas=len(data)
filas
# Out:
# 3935

# %% [markdown]
# En esta parte de la documentacion, mostramos los datos cargados mediante el uso de la libreria de Pandas, por lo que al revisar esta tabla se muesrra que es lo que contiene nuestra base de datos que cuenta con 3935 filas y 7 columnas

# %%
data.columns
# Out:
# Index(['Date', 'Price', 'Open', 'High', 'Low', 'Volume', 'Change'], dtype='object')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data.Date)
# Out:
# pandas.core.series.Series

# %%
type(data.Price)
# Out:
# pandas.core.series.Series

# %%
type(data.Open)
# Out:
# pandas.core.series.Series

# %%
type(data.High)
# Out:
# pandas.core.series.Series

# %%
type(data.Low)
# Out:
# pandas.core.series.Series

# %%
type(data.Volume)
# Out:
# pandas.core.series.Series

# %%
type(data.Change)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Por medio de estos comandos, encontramos las 7 columnas con sus respectivos tipos de datos como lo es Dataframe y series

# %%
pd.unique(data['Price']) #como se comporta el dato
# Out:
# array([5.04388e+04, 5.11830e+04, 5.20999e+04, ..., 3.00000e-01,
#        2.00000e-01, 1.00000e-01])

# %%
data['Price'].describe()
# Out:
# count     3935.000000
# mean      4334.106912
# std       8888.395159
# min          0.100000
# 25%         72.550000
# 50%        567.600000
# 75%       6583.550000
# max      63540.900000
# Name: Price, dtype: float64

# %%
data['Price'].std()
# Out:
# 8888.395158961683

# %%
data['Price'].median()
# Out:
# 567.6

# %%
data['Price'].mean()
# Out:
# 4334.1069123253

# %% [markdown]
# Al analizar estos datos tenemos una desviacion estandar muy alta por lo que me lleva a deducir que su precio es muy cambiante respecto a esta cryptomoneda, como media se tiene que el valor medio es de 567.6 y por ultimo se tiene un promedio de sus 3935 datos que se tiene registro desde julio de 2010 dando un valor de 4334.1069
